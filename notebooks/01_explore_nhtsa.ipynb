# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Projects\\AutoSentry-AI\\notebooks'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Projects\\AutoSentry-AI'

# %%
import json

with open("data/raw/honda_civic_2021_complaints.json", encoding="utf-8") as f:
    data = json.load(f)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['count', 'message', 'results'])

# %%
type(data["results"])
# Out:
# list

# %%
len(data["results"])
# Out:
# 144

# %%
data["results"][0]
# Out:
# {'odiNumber': 11765597,
#  'manufacturer': 'Honda (American Honda Motor Co.)',
#  'crash': False,
#  'fire': False,
#  'numberOfInjuries': 0,
#  'numberOfDeaths': 0,
#  'dateOfIncident': '09/17/2026',
#  'dateComplaintFiled': '09/20/2026',
#  'vin': '2HGFC2F60MH',
#  'components': 'STEERING,ELECTRICAL SYSTEM',
# ...

# %%
data["count"]
# Out:
# 144

# %%
data["results"][0].keys()
# Out:
# dict_keys(['odiNumber', 'manufacturer', 'crash', 'fire', 'numberOfInjuries', 'numberOfDeaths', 'dateOfIncident', 'dateComplaintFiled', 'vin', 'components', 'summary', 'products'])

# %%
data["results"][0]["summary"]
# Out:
# 'On September 17, 2026 at approximately 8:00 a.m. I was driving my 2021 Honda civic Lx with my children in the vehicle when multiple warning lights and system malfunction messages suddenly appeared on the dash board. The vehicle appeared to experience an electrical malfunction/ reset while still driving and I suddenly lost normal power- steering assistance. The steering wheel became extremely difficult to turn and control while the vehicle was moving.I was able to call for assistance and when jumper cables were hooked on to battery underneath the vehicles hood the vehicle engine was able to restart, then was able to get the vehicle home without a collision or injury. The sudden loss of steering assistance created a serious safety risk to me, my children and others on the road. I photographed multiple warnings displayed on the dash panel, including Electric Parking break problem and collision mitigation system problem. This vehicle has a documented history of electrical/ mechanical co
# ...

# %%
data["results"][0]["products"]
# Out:
# [{'type': 'Vehicle',
#   'productYear': '2021',
#   'productMake': 'HONDA',
#   'productModel': 'CIVIC',
#   'manufacturer': 'Honda (American Honda Motor Co.)'}]
